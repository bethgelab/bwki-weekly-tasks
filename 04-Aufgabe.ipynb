# %% [markdown]
# ## April Woche 4: Würfel

# %% [markdown]
# Willkommen zu unserer Aufgabe der Woche!
#
# Der Bundeswettbewerb Künstliche Intelligenz stellt euch jede Woche eine spannende oder kniffelige Programmieraufgabe, in der ihr euer Programmiergeschick auf die Probe stellen könnt.
#
# Jede Woche habt ihr die Chance auf einen von zwei Amazon-Gutscheinen im Wert von 25€! Wer jede Aufgabe in einem Monat einschickt, nimmt in der Monatsverlosung teil und kann einen 50€-Amazon-Gutschein gewinnen! Ihr könnt eure Lösung immer bis Sonntag 22 Uhr der gleichen Woche per Mail an aufgabe-der-woche@bw-ki.de einreichen.
#
# Bitte lade dazu das Notebook unter "File/Download as/Notebook (.ipynb)" runter. Verändere den Namen der Datei nicht und **vergiss nicht im ersten Feld deinen Name und deine E-Mailadresse anzugeben**.
#
# Es werden nur korrekte Lösungen berücksichtigt. Voraussetzung für die Teilnahme ist die Registrierung eures vollständigen Accounts im Loginbereich des Bundeswettbewerbs Künstliche Intelligenz. Es gelten die Teilnahmebedingungen (https://bw-ki.de/teilnahmebedingungen/ und Datenschuztrichtlinien (https://bw-ki.de/datenschutz/) des Wettbewerbs.

# %% [markdown]
# Dein vollständiger Name:
#
# Deine E-Mailadresse:

# %% [markdown]
# ## Die Würfel sind gefallen!

# %% [markdown]
# Die Aufgabe dieser Woche ist es, eine Würfelsimulation zu entwickeln. Oben zeigt der Würfel ein bis sechs Augen an, die den Wert des Wurfs angeben. Von schräg oben kann man jedoch drei Flächen des Würfels sehen, auf denen auch Augen sichtbar sind. Allerdings sind das, je nach dem wie der Würfel gefallen ist, nicht immer die selben Flächen.
#
# Die Würfelsimulation soll folgende Anforderungen erfüllen:
# * der Würfel soll zufällig generierte Augenzahlen anzeigen
# * auch die seitlichen Flächen sollen zufällige Augenzahlen anzeigen
# * alle Flächen des Würfels sollen korrekt und plausibel angezeigt werden, genau so wie sich ein echter Würfel verhält
#
# Du kannst mit einem echten Würfel testen, welche Flächen bei welchen Augenzahlen sichtbar sind.
#
# Du musst den folgenden Code bei "..." erweitern.

# %%
# Würfel ASCII Art Rohlinge als Vorlagen
# Die Zahlen sind Platzhalter für die Augen des Würfels
def wuerfel_vorlage_oben():
    return """
                       ######                     
                   ###        ##                  
               ####      333     ##               
            ###          333       ##             
        ###     222                  ###          
     ###        222             666     ###       
  ##                            666       ##      
 ##     111                                 ###   
 ####   111            555              999   ##  
 ##  ##                555              999     ##
 ##    ##     444                            #####
 ##      ##   444              888       ###    ##
 ##        ##                  888    ###       ##
 ##          ##                    ###          ##
 ##            ##     777       ###             ##
 ##              ##   777    ###                ##
 ##                ##     ###                   ##
 ##                  ####                       ##
 ##                   ##                        ##
  ##                  ##                        ##
    ##                ##                        ##
      ##              ##                     ###  
        ##            ##                  ###     
          ##          ##              ###         
            ##        ##           ###            
              ##      ##        ###               
                ##    ##     ###                  
                  ##  ##  ###                     
                    ######                        """

def wuerfel_vorlage_links():
    return """
                       ######                     
                   ###        ##                  
               ####              ##               
            ###                    ##             
        ###                          ###          
     ###                                ###       
  ##                                      ##      
 ##                                         ###   
 ####                                         ##  
 ##  ##                                         ##
 ##    ##                                    #####
 ## 11   ##                              ###    ##
 ##        ##                         ###       ##
 ##          ##                    ###          ##
 ## 44         ##               ###             ##
 ##        22    ##          ###                ##
 ##                ##     ###                   ##
 ##                  ####                       ##
 ## 77     55     33  ##                        ##
  ##                  ##                        ##
    ##                ##                        ##
      ##   88         ##                     ###  
        ##        66  ##                  ###     
          ##          ##              ###         
            ##        ##           ###            
              ##  99  ##        ###               
                ##    ##     ###                  
                  ##  ##  ###                     
                    ######                        """

def wuerfel_vorlage_rechts():
    return """
                       ######                     
                   ###        ##                  
               ####              ##               
            ###                    ##             
        ###                          ###          
     ###                                ###       
  ##                                      ##      
 ##                                         ###   
 ####                                         ##  
 ##  ##                                         ##
 ##    ##                                    #####
 ##      ##                              ###    ##
 ##        ##                         ###   33  ##
 ##          ##                    ###          ##
 ##            ##               ###             ##
 ##              ##          ###    22          ##
 ##                ##     ###               66  ##
 ##                  ####                       ##
 ##                   ##  11                    ##
  ##                  ##            55      99  ##
    ##                ##                        ##
      ##              ##                     ###  
        ##            ##  44        88    ###     
          ##          ##              ###         
            ##        ##           ###            
              ##      ##  77    ###               
                ##    ##     ###                  
                  ##  ##  ###                     
                    ######                        """

beispiel = """
                       ######
                   ###        ##
               ####      OOO     ##
            ###          OOO       ##
        ###                          ###
     ###                                ###
  ##                                      ##
 ##     OOO                                 ###
 ####   OOO                             OOO   ##
 ##  ##                                 OOO     ##
 ##    ##                                    #####
 ## OO   ##                              ###    ##
 ##        ##                         ###       ##
 ##          ##                    ###          ##
 ##            ##     OOO       ###             ##
 ##              ##   OOO    ###                ##
 ##                ##     ###                   ##
 ##                  ####                       ##
 ##                   ##                        ##
  ##                  ##            OO          ##
    ##                ##                        ##
      ##              ##                     ###
        ##            ##                  ###
          ##          ##              ###
            ##        ##           ###
              ##  OO  ##        ###
                ##    ##     ###
                  ##  ##  ###
                    ######"""
print(beispiel)

# %% [markdown]
# Mit diesen Rohlingen hast du alles was du brauchst, um einen simulierten Würfel zu fräsen. Aber achte darauf, dass der Würfel fair ist; Falschspielen ist nicht erlaubt!

# %%
# Zahl zu Augen-Nummern

# Von dieser Funktion soll eine Liste zurückgegeben werden, die die Nummern (Indices) der
# Augen enthält, die bei der Zahl eines Wurfs sichtbar sind.
# Das folgende Format für den Würfel soll eingehalten werden:
# -----------
# |1   2   3|
# |         |
# |4   5   6|
# |         |
# |7   8   9|
# -----------
# So wird z. B. ein Wurf der Zahl 5 durch die Liste [1, 3, 5, 7, 9] repräsentiert.
# Du kannst Elemente einer Liste mit der Funktion 'liste.append(ganzzahl)' anhängen.
def zahl_zu_augen_nummern(zahl):
    liste = []
    if zahl == 1:
        liste.append(5)
    if zahl == 2:
        liste.append(...)
        liste.append(...)
    if zahl == 3:
        ...
    if zahl == 4:
        ...
    if zahl == 5:
        ...
    if zahl == 6:
        ...
    return liste

# %% [markdown]
# Jetzt müssen die Augen an die richtige Stelle des Würfels.

# %%
# Augen auf dem Würfel

# In dieser Funktion sollen die Augen einer Seite auf dem Würfel abhängig von der Augenzahl
# richtig dargestellt werden. Schwarze ('ausgefüllte') Augen kannst du mit dem Buchstaben
# 'O' darstellen.

# Du kannst dazu string-Operationen verwenden, z. B. 'replace()':
# https://praxistipps.chip.de/python-string-replace-funktion-nutzen-so-gehts_95593
# Und Zahlen in Strings verwandeln:
# https://praxistipps.chip.de/python-int-to-string-so-gehts_94972
def wuerfel_augen(zahl, wuerfel_seite):
    # hole die richtig Vorlage
    wuerfel = ""
    if wuerfel_seite == "oben":
        wuerfel = wuerfel_vorlage_oben()
    if wuerfel_seite == ...:
        wuerfel = ...
    if wuerfel_seite == ...:
        wuerfel = ...
    
    # welche Augen müssen schwarz sein?
    liste_der_augen = zahl_zu_augen_nummern(zahl)
    
    # die Augen des Würfels müssen richtig ausgefüllt werden
    for i in ...:
        wuerfel = ...
    # Die restlichen Zahlen müssen aus dem Würfel entfernt werden
    for i in range(1, 10):
        wuerfel = wuerfel.replace(str(i), " ")
    
    return wuerfel

# überprüfe deine Funktion
print(wuerfel_augen(3, "oben"))
print(wuerfel_augen(5, "rechts"))
print(wuerfel_augen(2, "links"))

# %% [markdown]
# Im Prinzip ist der Würfel nun schon funktional, aber die Darstellung kann noch verbessert werden. Als nächstes wollen wir die verschiedenen Seiten des Würfels kombinieren.

# %%
# Mit dieser von uns fertig vorgegebenen Funktion kannst du Würfel-Rohlinge
# überlagernd kombinieren.
# Diese Funktion kannst du mit einem, zwei, oder drei Würfeln aufrufen.
def ueberlagere_wuerfel(*mehrere_wuerfel):
    wuerfel = ""
    for i in range(0, len(mehrere_wuerfel[0])):
        c = " "
        for j in range(0, len(mehrere_wuerfel)):
            if mehrere_wuerfel[j][i] != " ":
                c = mehrere_wuerfel[j][i]
        wuerfel += c
    return wuerfel

# %%
# Um eine zufällige Zahl zu würfeln, verwenden wir das Modul random.
# https://www.python-lernen.de/zufallszahlen-random.htm
import random

# Augen an den Seiten des Würfels

# In dieser Funktion sollen nun zusätzlich die Augen an den Seiten des Würfels
# abhängig von der Augenzahl oben richtig dargestellt werden.
# Schwarze ('ausgefüllte') Augen kannst du mit dem Buchstaben 'O' darstellen,
# weiße Augen mit Leerzeichen. Du kannst dazu wieder string-Operationen verwenden.

# Implementiere außerdem, dass die Funktion als Eingabewerte nur Ganzzahlen
# von einschließlich 1 bis 6 akzeptiert.
def erstelle_wuerfel(zahl_oben):
    
    # überprüfe den Eingabewert
    moegliche_zahlen = [1, 2, 3, 4, 5, 6]
    if ...:
        print("Fehler! Würfel können nur die Zahlen von 1 bis 6 anzeigen!")
    
    # Entferne die Zahlen, die oben und unten liegen aus der Liste moegliche_zahlen, 
    # da diese nicht an der Seite angezeigt werden können. Verwende dazu 'list.remove()'
    moegliche_zahlen.remove(zahl_oben)
    moegliche_zahlen.remove(...)
    
    # Wähle eine Zahl für die linke Seite
    # Eine Zufallszahl zwischen einschließlich 1 und 6 erzeugst du mit 'random.randint(1, 6)'.
    # Dazu haben wir oben das random-Modul importiert: 'import random'.
    # achte darauf, dass das nicht die Zahl oben oder unten auf dem Würfel sein darf.
    zahl_links = ...
    
    # Entferne die Zahl der linken Seite und ihrer Rückseite aus der Liste und
    # bestimme die Zahl auf der rechten Seite.
    zahl_rechts = ...
    
    # hole die Würfel mit den fertig ausgefüllten Augen
    wuerfel_oben = wuerfel_augen(zahl_oben, "oben")
    wuerfel_links = wuerfel_augen(zahl_links, "links")
    wuerfel_rechts = wuerfel_augen(zahl_rechts, "rechts")
        
    # kombiniere die Rohlinge überlagernd zu einem Würfel und gebe den Würfel zurück
    wuerfel = ueberlagere_wuerfel(wuerfel_oben, wuerfel_links, wuerfel_rechts)
    
    return wuerfel

# überprüfe deine Funktion
zufallszahl = random.randint(1, 6)
print(erstelle_wuerfel(zufallszahl))

# %% [markdown]
# ## Zusatzaufgabe:
#
# Schreibe eine Funktion, die zwei Würfel nebeneinander darstellt.
# Diese Aufgabe ist nicht relevant für das Gewinnspiel.
#
# Das Wort 'Pasch' entstammt dem Französischen und ist von 'passe-dix' abgeleitet. Wörtlich bedeutet das 'überschreite zehn'. Nun soll es möglich sein, dass zwei Würfel unabhängig voneinander geworfen werden und diese nebeneinander dargestellt werden.

# %%
# Zwei Würfel nebeneinander

# In der Funktion werden zwei Zufallszahlen zwischen 1 und 6 generiert und damit
# die Zeichenketten von zwei Würfeln mit den bereits implementierten Funktionen erzeugt.

# Dann werden die beiden Zeichenketten so kombiniert, dass die Würfel nebeneinander angezeigt werden,
# ohne dass die Würfel verzerrt oder falsch angezeigt werden.

def zwei_wuerfel():
    # erstelle die beiden Würfel
    zufallszahl_1 = random.randint(1, 6)
    zufallszahl_2 = random.randint(1, 6)
    wuerfel_1 = erstelle_wuerfel(zufallszahl_1)
    wuerfel_2 = erstelle_wuerfel(zufallszahl_2)
    
    # trenne die Zeichenketten nach Zeilen auf
    ...
    
    # initialisiere den Rückgabewert
    beide_wuerfel = ""
    
    # kombiniere die beiden Würfel zeilenweise
    ...
    
    return beide_wuerfel
    
# überprüfe deine Funktion
print(zwei_wuerfel())

# %% [markdown]
# Super! Jetzt brauchst du nicht immer einen Würfel mitzunehmen, sondern kannst diese Simulation verwenden!

# %% [markdown]
# ## Feedback für uns (freiwillig)
# War diese Aufgabe zu leicht, zu schwer oder genau richtig?
#
# Wie lang hast du für diese Aufgabe ungefähr gebraucht?
#
# Welche Art von Aufgaben wünschst du dir in Zukunft?
